# %% [markdown]
# importing required packages

# %%
import numpy as n
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s

plt.style.use('fivethirtyeight')
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import data

# %%
print(s.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
cc_df=s.load_dataset('car_crashes')
cc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# distribution plot

# %%
s.distplot(cc_df['not_distracted'])
# Out:
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %%
s.distplot(cc_df['not_distracted'],kde=False)
# Out:
# <AxesSubplot:xlabel='not_distracted'>

# %%
s.distplot(cc_df['not_distracted'],kde=False,bins=8,hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='not_distracted'>
